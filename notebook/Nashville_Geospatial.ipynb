# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
nash_weather = pd.read_csv('../data/weather_stats.csv')
nash_weather = nash_weather[['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'DATE', 'TAVG', 'TMAX', 'TMIN']]
nash_weather = nash_weather.rename({'TAVG': 'temp_avg', 'TMAX':'temp_max', 'TMIN':'temp_min'}, axis =1)
nash_weather['DATE'] = pd.to_datetime(nash_weather['DATE'])

# %%
nash_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37056 entries, 0 to 37055
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATION    37056 non-null  object
#  1   NAME       37056 non-null  object
#  2   LATITUDE   37056 non-null  float64
#  3   LONGITUDE  37056 non-null  float64
#  4   DATE       37056 non-null  datetime64[ns]
#  5   temp_avg   808 non-null    float64
#  6   temp_max   7535 non-null   float64
#  7   temp_min   7535 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 2.3+ MB

# %%
nash_weather['geometry'] = nash_weather.apply(lambda x: Point((float(x.LONGITUDE), 
                                                         float(x.LATITUDE))), 
                                        axis=1)
nash_weather.head(50)
# Out:
#         STATION                             NAME   LATITUDE  LONGITUDE  \
# 0   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 1   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 2   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 3   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 4   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 5   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 6   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 7   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 8   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 9   US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 10  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 11  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 12  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 13  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 14  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 15  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 16  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 17  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 18  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 19  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 20  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 21  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 22  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 23  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 24  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 25  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 26  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 27  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 28  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 29  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 30  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 31  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 32  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 33  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 34  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 35  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 36  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 37  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 38  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 39  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 40  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 41  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 42  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 43  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 44  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 45  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 46  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 47  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 48  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
# 49  US1TNCH0002  KINGSTON SPRINGS 0.3 ENE, TN US  36.098414 -87.096259
#
#          DATE  temp_avg  temp_max  temp_min                      geometry
# 0  2020-03-01       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 1  2020-03-02       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 2  2020-03-03       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 3  2020-03-04       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 4  2020-03-05       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 5  2020-03-06       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 6  2020-03-07       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 7  2020-03-08       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 8  2020-03-09       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 9  2020-03-10       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 10 2020-03-11       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 11 2020-03-12       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 12 2020-03-13       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 13 2020-03-14       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 14 2020-03-15       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 15 2020-03-16       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 16 2020-03-17       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 17 2020-03-18       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 18 2020-03-19       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 19 2020-03-20       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 20 2020-03-21       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 21 2020-03-22       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 22 2020-03-23       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 23 2020-03-24       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 24 2020-03-25       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 25 2020-03-26       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 26 2020-03-27       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 27 2020-03-28       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 28 2020-03-29       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 29 2020-03-30       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 30 2020-03-31       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 31 2020-04-01       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 32 2020-04-02       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 33 2020-04-03       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 34 2020-04-04       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 35 2020-04-05       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 36 2020-04-06       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 37 2020-04-07       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 38 2020-04-08       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 39 2020-04-09       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 40 2020-04-10       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 41 2020-04-11       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 42 2020-04-12       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 43 2020-04-13       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 44 2020-04-14       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 45 2020-04-15       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 46 2020-04-16       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 47 2020-04-17       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 48 2020-04-18       NaN       NaN       NaN  POINT (-87.096259 36.098414)
# 49 2020-04-19       NaN       NaN       NaN  POINT (-87.096259 36.098414)

# %%
nash_weather['NAME'].value_counts()
# Out:
# MOUNT JULIET 6.1 SSW, TN US               412
# NASHVILLE INTERNATIONAL AIRPORT, TN US    412
# FRANKLIN 4.4 W, TN US                     412
# MURFREESBORO 5.5 NNW, TN US               412
# SMYRNA 3.0 ESE, TN US                     412
#                                          ...
# GREENBRIER 1.4 N, TN US                    34
# NASHVILLE 6.7 SE, TN US                    11
# PLEASANT VIEW 2.8 ESE, TN US                5
# ARRINGTON 1.3 NNE, TN US                    4
# OLD HICKORY 1.2 SSE, TN US                  1
# Name: NAME, Length: 118, dtype: int64

# %%
zipcodes = gpd.read_file('../data/zipcodes.geojson')

# %%
zipcodes = zipcodes[['zip', 'geometry']]
zipcodes.head()
# Out:
#      zip                                           geometry
# 0  37115  MULTIPOLYGON (((-86.68725 36.31821, -86.68722 ...
# 1  37216  MULTIPOLYGON (((-86.73451 36.23774, -86.73425 ...
# 2  37204  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...
# 3  37027  MULTIPOLYGON (((-86.81258 36.06319, -86.81263 ...
# 4  37064  MULTIPOLYGON (((-87.02197 36.01200, -87.02140 ...

# %%
covid_cases = pd.read_csv('../data/COVID_CountByZipPerDate 03292021.csv')
covid_cases = covid_cases.rename(columns = {'Specimen Collection Date' : 'date', 'Zip':'zip','Cases':'cases'})
covid_cases['zip'] = covid_cases['zip'].astype('Int64')
covid_cases['zip'] = covid_cases['zip'].astype('str')
covid_cases['date'] = pd.to_datetime(covid_cases['date'])
covid_cases.head()
# Out:
#         date    zip  cases
# 0 2020-03-06  37217      1
# 1 2020-03-10  37214      1
# 2 2020-03-11  37013      1
# 3 2020-03-11  37204      2
# 4 2020-03-11  37205      1

# %%
covid_cases = covid_cases.merge(zipcodes, how = 'left', on = 'zip')
covid_cases.head()
# Out:
#         date    zip  cases                                           geometry
# 0 2020-03-06  37217      1  MULTIPOLYGON (((-86.67355 36.12729, -86.66687 ...
# 1 2020-03-10  37214      1  MULTIPOLYGON (((-86.65585 36.11824, -86.66410 ...
# 2 2020-03-11  37013      1  MULTIPOLYGON (((-86.66517 36.09108, -86.66526 ...
# 3 2020-03-11  37204      2  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...
# 4 2020-03-11  37205      1  MULTIPOLYGON (((-86.81907 36.13351, -86.81688 ...
